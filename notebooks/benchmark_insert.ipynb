# %%
from core.benchmark_insert import generate_result
from core.utils.constants import Extension, Dataset, DEFAULT_INDEX_PARAMS
for extension in Extension:
    generate_result(extension, Dataset.SIFT, '100k', index_params=DEFAULT_INDEX_PARAMS[extension])
# Out:
# extension: pgvector_ivfflat, index params: {'lists': 100, 'probes': 16}, dataset: sift
# N                  TPS                Avg Latency (ms)   Stddev Latency (ms)
# ----------------------------------------------------------------------------
# 10000 - 10999      1059.45            0.94               0.16
# 11000 - 11999      1024.23            0.97               0.23
# 12000 - 12999      1043.98            0.96               0.14
# 13000 - 13999      942.20             1.06               2.16
# 14000 - 14999      1062.39            0.94               0.13
# 15000 - 15999      1065.91            0.94               0.14
# 16000 - 16999      1082.81            0.92               0.13
# 17000 - 17999      1032.79            0.97               0.13
# 18000 - 18999      1047.03            0.95               0.13
# 19000 - 19999      1044.45            0.96               0.15
# 20000 - 20999      1045.81            0.95               0.12
# 21000 - 21999      1030.52            0.97               0.15
# 22000 - 22999      1037.40            0.96               0.16
# 23000 - 23999      1023.85            0.98               0.18
# 24000 - 24999      1053.05            0.95               0.13
# 25000 - 25999      1061.20            0.94               0.15
# 26000 - 26999      1040.63            0.96               0.14
# 27000 - 27999      1019.88            0.98               0.14
# 28000 - 28999      1028.87            0.97               0.14
# 29000 - 29999      1063.00            0.94               0.17
# 30000 - 30999      1026.79            0.97               0.15
# 31000 - 31999      1017.96            0.98               0.25
# 32000 - 32999      1055.12            0.95               0.17
# 33000 - 33999      1040.13            0.96               0.14
# 34000 - 34999      1057.53            0.94               0.14
# 35000 - 35999      1023.09            0.98               0.13
# 36000 - 36999      1039.49            0.96               0.17
# 37000 - 37999      1068.99            0.94               0.13
# 38000 - 38999      1048.47            0.95               0.15
# 39000 - 39999      1057.11            0.94               0.12
# 40000 - 40999      1049.52            0.95               0.12
# 41000 - 41999      1080.72            0.92               0.14
# 42000 - 42999      1056.35            0.95               0.27
# 43000 - 43999      980.76             1.02               1.85
# 44000 - 44999      1090.65            0.92               0.13
# 45000 - 45999      1084.98            0.92               0.14
# 46000 - 46999      1046.84            0.95               0.21
# 47000 - 47999      1070.12            0.93               0.15
# 48000 - 48999      1089.50            0.92               0.15
# 49000 - 49999      1099.76            0.91               0.14
# 50000 - 50999      1082.19            0.92               0.14
# 51000 - 51999      1081.22            0.92               0.15
# 52000 - 52999      1058.43            0.94               0.16
# 53000 - 53999      1085.30            0.92               0.13
# 54000 - 54999      1066.15            0.94               0.23
# 55000 - 55999      1083.84            0.92               0.13
# 56000 - 56999      1071.26            0.93               0.14
# 57000 - 57999      1016.53            0.98               0.17
# 58000 - 58999      1063.14            0.94               0.12
# 59000 - 59999      1061.96            0.94               0.23
# 60000 - 60999      1097.52            0.91               0.13
# 61000 - 61999      1081.51            0.92               0.16
# 62000 - 62999      1090.12            0.92               0.13
# 63000 - 63999      1093.36            0.91               0.12
# 64000 - 64999      1120.66            0.89               0.12
# 65000 - 65999      1054.26            0.95               0.34
# 66000 - 66999      1077.05            0.93               0.11
# 67000 - 67999      1033.87            0.97               0.18
# 68000 - 68999      1015.85            0.98               0.13
# 69000 - 69999      1024.17            0.97               0.13
# 70000 - 70999      1032.20            0.97               0.15
# 71000 - 71999      1010.64            0.99               0.19
# 72000 - 72999      1024.36            0.97               0.15
# 73000 - 73999      1016.86            0.98               0.13
# 74000 - 74999      959.95             1.04               1.48
# 75000 - 75999      1036.15            0.96               0.20
# 76000 - 76999      1001.05            1.00               0.15
# 77000 - 77999      1005.95            0.99               0.24
# 78000 - 78999      1029.46            0.97               0.16
# 79000 - 79999      999.54             1.00               0.20
# 80000 - 80999      1005.22            0.99               0.14
# 81000 - 81999      1005.27            0.99               0.19
# 82000 - 82999      964.14             1.04               0.14
# 83000 - 83999      934.22             1.07               0.14
# 84000 - 84999      935.09             1.07               0.13
# 85000 - 85999      931.93             1.07               0.26
# 86000 - 86999      909.84             1.10               0.25
# 87000 - 87999      905.54             1.10               0.19
# 88000 - 88999      953.94             1.05               0.13
# 89000 - 89999      936.58             1.07               0.14
# 90000 - 90999      946.05             1.06               0.14
# 91000 - 91999      1003.24            1.00               0.13
# 92000 - 92999      929.30             1.07               0.35
# 93000 - 93999      957.44             1.04               0.16
# 94000 - 94999      978.64             1.02               0.14
# 95000 - 95999      972.92             1.03               0.16
# 96000 - 96999      1004.44            0.99               0.14
# 97000 - 97999      966.65             1.03               0.33
# 98000 - 98999      1033.23            0.97               0.13
# 99000 - 99999      1051.59            0.95               0.12
#
# extension: pgvector_hnsw, index params: {'m': 32, 'ef_construction': 128, 'ef': 10}, dataset: sift
# N                  TPS                Avg Latency (ms)   Stddev Latency (ms)
# ----------------------------------------------------------------------------
# 10000 - 10999      119.96             8.33               2.24
# 11000 - 11999      112.36             8.90               2.44
# 12000 - 12999      129.03             7.75               0.85
# 13000 - 13999      96.66              10.34              2.58
# 14000 - 14999      96.42              10.37              2.63
# 15000 - 15999      87.78              11.39              2.68
# 16000 - 16999      125.05             8.00               0.88
# 17000 - 17999      123.96             8.06               0.85
# 18000 - 18999      79.91              12.51              2.56
# 19000 - 19999      117.01             8.54               0.86
# 20000 - 20999      116.77             8.56               0.96
# 21000 - 21999      76.85              13.01              2.47
# 22000 - 22999      115.59             8.65               1.27
# 23000 - 23999      91.00              10.99              3.28
# 24000 - 24999      126.73             7.89               1.25
# 25000 - 25999      86.23              11.60              3.08
# 26000 - 26999      121.72             8.21               1.31
# 27000 - 27999      120.27             8.31               1.21
# 28000 - 28999      120.24             8.31               1.28
# 29000 - 29999      121.76             8.21               1.33
# 30000 - 30999      88.67              11.28              3.48
# 31000 - 31999      72.99              13.70              2.76
# 32000 - 32999      108.16             9.24               1.21
# 33000 - 33999      106.86             9.36               1.32
# 34000 - 34999      69.81              14.32              2.64
# 35000 - 35999      70.13              14.26              2.38
# 36000 - 36999      76.80              13.02              2.87
# 37000 - 37999      86.02              11.62              3.97
# 38000 - 38999      127.32             7.85               2.62
# 39000 - 39999      112.52             8.88               3.31
# 40000 - 40999      81.98              12.20              3.30
# 41000 - 41999      87.76              11.39              3.51
# 42000 - 42999      84.77              11.79              3.19
# 43000 - 43999      85.77              11.66              3.39
# 44000 - 44999      83.47              11.98              3.49
# 45000 - 45999      84.15              11.88              3.39
# 46000 - 46999      87.06              11.48              3.32
# 47000 - 47999      77.20              12.95              3.24
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       2 from core.utils.constants import Extension, Dataset, DEFAULT_INDEX_PARAMS
#       3 for extension in Extension:
# ----> 4     generate_result(extension, Dataset.SIFT, '100k', index_params=DEFAULT_INDEX_PARAMS[extension])
#
# File /workspaces/benchmark/core/benchmark_insert.py:141, in generate_result(extension, dataset, N_string, index_params, bulk, K)
#     129 def save_insert_result(metric_type, metric_value):
#     130     save_result(
#     131         metric_type,
#     132         metric_value,
#    (...)
#     138         err=stderr,
#     139     )
# --> 141 save_insert_result(get_latency_metric(bulk), latency_average)
#     142 save_insert_result(get_latency_stddev_metric(bulk), latency_stddev)
#     143 save_insert_result(get_tps_metric(bulk), tps)
#
# File /workspaces/benchmark/core/benchmark_insert.py:130, in generate_result.<locals>.save_insert_result(metric_type, metric_value)
#     129 def save_insert_result(metric_type, metric_value):
# --> 130     save_result(
#     131         metric_type,
#     132         metric_value,
#     133         extension=extension,
#     134         index_params=index_params,
#     135         dataset=dataset,
#     136         n=iter_N + 1000,
#     137         out=stdout,
#     138         err=stderr,
#     139     )
#
# File /workspaces/benchmark/core/utils/process.py:153, in save_result(metric_type, metric_value, extension, index_params, dataset, n, k, out, err)
#     139 sql = f"""
#     140     INSERT INTO
#     141         experiment_results ({columns})
#    (...)
#     147         {updates}
#     148 """
#     150 data = (
#     151     extension.value, json.dumps(index_params), dataset.value, n, k, metric_type.value, metric_value, out, err)
# --> 153 with DatabaseConnection() as conn:
#     154     conn.execute(sql, data=data)
#
# File /workspaces/benchmark/core/utils/database.py:17, in DatabaseConnection.__enter__(self)
#      16 def __enter__(self):
# ---> 17     self.conn = psycopg2.connect(get_database_url(self.extension))
#      18     self.conn.autocommit = self.autocommit
#      19     self.cur = self.conn.cursor()
#
# File /usr/local/lib/python3.11/dist-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (127.0.0.1), port 5432 failed: FATAL:  the database system is in recovery mode

# %%
from core.utils.constants import Dataset
from core.benchmark_insert import print_results

print_results(Dataset.SIFT)

# %%
from core.utils.constants import Dataset
from notebooks.plot_insert_benchmarks import plot_results

plot_results(Dataset.SIFT)
