# %% [markdown]
# # Generate data

# %%
from recall import generate_data
K = [5, 10, 20, 30]
# generate_data('pgvector', 'sift', ['10k', '1m'], K)
generate_data('lantern', 'sift', ['10k', '1m'], K)
generate_data('pgvector', 'gist', ['1m'], K)
generate_data('lantern', 'gist', ['1m'], K)
# Out:
# about to calculate recall for extension=lantern, dataset=sift
# about to calculate recall for extension=lantern, dataset=sift, N=10k
# recall @ 5 for query_id 1: 5
# recall @ 5 for query_id 2: 5
# recall @ 5 for query_id 3: 5
# recall @ 5 for query_id 4: 5
# recall @ 5 for query_id 5: 5
# recall @ 5 for query_id 6: 5
# recall @ 5 for query_id 7: 5
# recall @ 5 for query_id 8: 5
# recall @ 5 for query_id 9: 5
# recall @ 5 for query_id 10: 5
# recall @ 5 for query_id 11: 5
# recall @ 5 for query_id 12: 5
# recall @ 5 for query_id 13: 5
# recall @ 5 for query_id 14: 5
# recall @ 5 for query_id 15: 5
# recall @ 5 for query_id 16: 5
# recall @ 5 for query_id 17: 5
# recall @ 5 for query_id 18: 5
# recall @ 5 for query_id 19: 5
# recall @ 5 for query_id 20: 5
# recall @ 5 for query_id 21: 5
# recall @ 5 for query_id 22: 5
# recall @ 5 for query_id 23: 5
# recall @ 5 for query_id 24: 5
# recall @ 5 for query_id 25: 5
# recall @ 5 for query_id 26: 5
# recall @ 5 for query_id 27: 5
# ...

# %% [markdown]
# # Parse data and generate plots

# %%
from recall import plot_data
plot_data('pgvector', 'sift')
plot_data('lantern', 'sift')
plot_data('pgvector', 'gist')
plot_data('lantern', 'gist')
